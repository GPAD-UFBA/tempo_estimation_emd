# %%
import numpy as np
from upemd import  UPEMD

# %%
import matplotlib.pyplot as plt

# %%
sample_rate = 1000
seconds = 10
num_samples = sample_rate*seconds

time_vect = np.linspace(0, seconds, num_samples)
freq = 5

# %%
x = np.cos(2 * np.pi * 1 * time_vect)
x += np.sin(2 * np.pi * 2.2e-1 * time_vect)

# %%
plt.plot(x)

# %%
upemd = UPEMD()

# %%
imfs = upemd.upemd(x)
# Out:
# (1, 20000)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Projetos_hd\tempo_estimation_emd\src\features\exploratory.ipynb Célula: 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Projetos_hd/tempo_estimation_emd/src/features/exploratory.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> imfs = upemd.upemd(x)
#
# File d:\Projetos_hd\tempo_estimation_emd\src\features\upemd.py:106, in UPEMD.upemd(self, raw_signal)
#     104 self.validate_parameters(raw_signal)
#     105 self.res = self.signal
# --> 106 return self.make_modes()
#
# File d:\Projetos_hd\tempo_estimation_emd\src\features\upemd.py:94, in UPEMD.make_modes(self)
#      91 self.media_array = sinusoidal_wave(2*self.n_data,self.amp_sin,(self.num_shift/2))
#      92 self.sum_wrk = np.zeros((1,self.n_data))
# ---> 94 self.make_shift()
#      96 imf[self.count_mode,:] = self.sum_wrk/self.count_shift
#      97 self.res = self.res - imf[self.count_mode,:]
#
# File d:\Projetos_hd\tempo_estimation_emd\src\features\upemd.py:74, in UPEMD.make_shift(self)
#      70 self.count_shift += 1
#      72 self.y = self.res + media
# ---> 74 sub_imf = emd.sift.sift(x, **conf)
#      75 sub_imf = np.transpose(sub_imf)
#      76 sub_imf[0,:] = sub_imf[0,:] - media
#
# NameError: name 'x' is not defined

# %%
len(np.array([1,2,3]))
# Out:
# 3
